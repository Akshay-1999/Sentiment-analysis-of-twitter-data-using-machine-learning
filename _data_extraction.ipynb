# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install tweepy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import tweepy
import tweepy as tw
# your Twitter API key and API secret
my_api_key = "9TmYoApVHdw3CjXDceBNlMYna"
my_api_secret = "mUrWA0WoYT1oPz49eZvwAYi0t3qDJCSVOzEiM0nnZGyt7oga4D"
# authenticate
auth = tw.OAuthHandler(my_api_key, my_api_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
search_query = "#russia ukraine war"

# %%
# get tweets from the API
tweets = tw.Cursor(api.search,
              q=search_query,
              lang="en",
              since="2022-02-22").items(20)
# store the API responses in a list
tweets_copy = []
for tweet in tweets:
    tweets_copy.append(tweet)
    
print("Total Tweets fetched:", len(tweets_copy))
# Out:
# Total Tweets fetched: 20

# %%
import pandas as pd
# intialize the dataframe
tweets_df = pd.DataFrame()
# populate the dataframe
for tweet in tweets_copy:
    hashtags = []
    try:
        for hashtag in tweet.entities["hashtags"]:
            hashtags.append(hashtag["text"])
        text = api.get_status(id=tweet.id, tweet_mode='extended').full_text
    except:
        pass
    tweets_df = tweets_df.append(pd.DataFrame({'user_name': tweet.user.name, 
                                               'user_location': tweet.user.location,\
                                               'user_description': tweet.user.description,
                                               'user_verified': tweet.user.verified,
                                               'date': tweet.created_at,
                                               'text': text, 
                                               'hashtags': [hashtags if hashtags else None],
                                               'source': tweet.source}))
    tweets_df = tweets_df.reset_index(drop=True)
# show the dataframe
tweets_df.head()
# Out:
#             user_name  user_location  \
# 0  GlobalData Defense         Global
# 1               Herry      Indonesia
# 2       SWFL Warriors  Cape Coral FL
# 3       SWFL Warriors  Cape Coral FL
# 4       SWFL Warriors  Cape Coral FL
#
#                                     user_description  user_verified  \
# 0  We have a long history of providing reliable i...          False
# 1  Compassion for the poor and the oppressed. Cou...          False
# 2  Volunteers in The Ukraine War!\nCurrently rais...          False
# 3  Volunteers in The Ukraine War!\nCurrently rais...          False
# 4  Volunteers in The Ukraine War!\nCurrently rais...          False
#
#                  date                                               text  \
# 0 2022-06-24 08:22:12  The #Russia-Ukraine war has led to countries i...
# 1 2022-06-24 08:22:02  RT @HerryNapit: Ukraine war: Tell mother Russi...
# 2 2022-06-24 08:20:33  Article Link: https://t.co/5YEgEil9EA \nUkrain...
# ...

# %%
from google.colab import files
tweets_df.to_csv('russia ukraine war train.csv') 
files.download('russia ukraine war train.csv')
